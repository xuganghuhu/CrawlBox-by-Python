# %%
from bs4 import BeautifulSoup 
import urllib
import urllib.request
import pandas as pd
import numpy as np

# %% [markdown]
# # 《非常6+1》

# %%
## 短评
comment=[]
url_bas='https://movie.douban.com/subject/25949771/comments?start='
for i in range(0,180,20):
    url=url_bas+str(i)+'&limit=20&sort=new_score&status=P'
    html=urllib.request.urlopen(url)
    soup=BeautifulSoup(html,'html.parser')
    obj=soup.find_all('span',class_='short')
    for i in obj:
        comment.append(i.text)

# %%
## 评论时间
date=[]
url_bas='https://movie.douban.com/subject/25949771/comments?start='
for i in range(0,180,20):
    url=url_bas+str(i)+'&limit=20&sort=new_score&status=P'
    html=urllib.request.urlopen(url)
    soup=BeautifulSoup(html,'html.parser')
    obj=soup.find_all('span',class_='comment-time')
    for i in obj:
        date.append(i.text)

# %%
## 支持数
support=[]
url_bas='https://movie.douban.com/subject/25949771/comments?start='
for i in range(0,180,20):
    url=url_bas+str(i)+'&limit=20&sort=new_score&status=P'
    html=urllib.request.urlopen(url)
    soup=BeautifulSoup(html,'html.parser')
    obj=soup.find_all('span',class_='votes')
    for i in obj:
        support.append(i.text)

# %%
data=pd.DataFrame({'date':date,'comment':comment,'support':support})
data.sort_values('date',ascending=True)
# Out:
#                                                comment  \
# 4                                         才艺展示+砸金蛋，还行。
# 27                                                  李咏
# 102                                                 砸蛋
# 83                                         这个绝对洗脑，必须标记
# 61                                        李咏的节目越来越没意思。
# 156                      小时候全家必看，这些年节目不行了，我也长大了，就没看过了。
# 2                           李咏的节目印象最深就是《非常6+1》和《幸运52》。
# 0                                 央视被各大卫视赶超后就从未有过赶超之心。
# 52                                     李咏主持的栏目里从来没看过这个
# 17                                            何等古老的···
# 110                  越做越差的节目，而且冠军并没有得到更多的机会，只是在央视跑场子而已
# 116                                                滚粗！
# 86                                      为什么换掉正大综艺 不理解。
# 57                                                   *
# 9                                                手势，手势
# 109           砸金蛋好看，打电话的时候还有人以为李咏是骗子，有点意思。但除了砸金蛋就没亮点了。
# 3                                     马脸那销魂无比的手势来砸金蛋银蛋
# 34                                                 咏哥，
# 106  圆梦节目鼻祖之一w 一直想帮忙砸金蛋2333 李咏一是幸运52二是非常6+1，非常6+1那时...
# 177                                            只记得砸金蛋了
# 39                                     小時候全家不看完不睡覺系列3。
# 56                                                 李咏。
# 175                           非常星发布还可以看看，歌友会一样，不过都是假唱。
# 142                                   以前还挺好看的，可惜后来越做越差
# 42                                                mark
# 95                                                  俗。
# 94                                              很烦主持人。
# 7                                          常用标签里怎么没有马脸
# 78                                          只记得砸金蛋了。。。
# 138                                               瞬间石化
# ..                                                 ...
# 84                                            李咏老师一路走好
# 123                                           李咏老师一路走好
# 77                        小时候总在想，什么时候李咏老师才会来问我要砸哪个金蛋呢？
# 125                                             童年的记忆。
# 126                                                 走好
# 127  伴随我童年的人 今天 突然知道他去世了 我希望在这里借用这种方式去怀念他 每个人的人生都只有...
# 15                                                  走好
# 14                                              李咏老师走好
# 69                                             愿天堂没有癌症
# 64                         怀念。纪念。那些小时候合家欢的日子以及逝去的李咏叔叔。
# 146                                  可惜了，这么好的主持人！珍惜身边人
# 29                                       金花四溅的金蛋一期多一期少
# 12                 人生真是不知明天和意外哪个先来，李咏老师一路走好，感谢曾经节目的陪伴。
# 134                                              童年回忆啊
# 144                           我小时候也是多么渴望砸金蛋啊，总在猜哪个是金蛋。
# 143                                            哎，世事无常！
# 11                             很经典的一档节目，童年回忆，李咏老师一路走好🙏
# 22                            我是主持人李咏，我们下期节目再见！真的再见了……
# 13                             6＋1没少看，今天听到消息很震惊，咏哥一路走好
# 85                                                纪念李咏
# 90                                    一晃好多年，90后开始失去了……
# 162                                        儿时的记忆，永远记得。
# 161                                       美好的记忆 咏哥一路走好
# 135                                  为自己童年看过的节目打个卡，再见。
# 159  依稀记得小时候看这个节目，李咏叔叔幽默风趣，长发西服，帅气。转眼人已逝去，愿在天堂安好。岁月...
# 164                            小时候晚上非常喜欢看的节目，记忆犹新的是砸金蛋
# 178              看李咏节目长大的 听老李说妈妈住院的时候还有帮到很大的忙 愿天堂没有病痛
# 166                                                 珍惜
# 150  通过非常6+1和幸运52认识李咏，个性的头发，幽默的语言，精美的礼服，平易近人的笑容，一路走...
# 49                                    看过几期，很喜欢李咏的主持风格！
#
#                                                   date support
# 4    \n                    2015-01-13\n            ...       4
# 27   \n                    2015-01-19\n            ...       0
# 102  \n                    2015-03-26\n            ...       0
# 83   \n                    2015-04-22\n            ...       0
# 61   \n                    2015-04-26\n            ...       0
# 156  \n                    2015-05-10\n            ...       0
# 2    \n                    2015-07-04\n            ...       8
# 0    \n                    2015-07-05\n            ...      17
# 52   \n                    2015-07-13\n            ...       0
# 17   \n                    2015-07-15\n            ...       1
# 110  \n                    2015-07-18\n            ...       0
# 116  \n                    2015-07-21\n            ...       0
# 86   \n                    2015-07-23\n            ...       0
# 57   \n                    2015-08-08\n            ...       0
# 9    \n                    2015-08-19\n            ...       2
# 109  \n                    2015-09-03\n            ...       0
# 3    \n                    2015-11-09\n            ...      13
# 34   \n                    2015-12-29\n            ...       0
# 106  \n                    2016-01-27\n            ...       0
# 177  \n                    2016-02-06\n            ...       0
# 39   \n                    2016-02-08\n            ...       0
# 56   \n                    2016-02-08\n            ...       0
# 175  \n                    2016-03-27\n            ...       0
# 142  \n                    2016-04-16\n            ...       0
# 42   \n                    2016-05-23\n            ...       0
# 95   \n                    2016-06-24\n            ...       0
# 94   \n                    2016-07-17\n            ...       0
# 7    \n                    2016-07-19\n            ...       2
# 78   \n                    2016-07-25\n            ...       0
# 138  \n                    2016-07-28\n            ...       0
# ..                                                 ...     ...
# 84   \n                    2018-10-29\n            ...       1
# 123  \n                    2018-10-29\n            ...       1
# 77   \n                    2018-10-29\n            ...       0
# 125  \n                    2018-10-29\n            ...       1
# 126  \n                    2018-10-29\n            ...       0
# 127  \n                    2018-10-29\n            ...       2
# 15   \n                    2018-10-29\n            ...       4
# 14   \n                    2018-10-29\n            ...       2
# 69   \n                    2018-10-29\n            ...       0
# 64   \n                    2018-10-29\n            ...       1
# 146  \n                    2018-10-29\n            ...       0
# 29   \n                    2018-10-29\n            ...       0
# 12   \n                    2018-10-29\n            ...       3
# 134  \n                    2018-10-29\n            ...       1
# 144  \n                    2018-10-29\n            ...       0
# 143  \n                    2018-10-29\n            ...       1
# 11   \n                    2018-10-29\n            ...       4
# 22   \n                    2018-10-29\n            ...       5
# 13   \n                    2018-10-29\n            ...       3
# 85   \n                    2018-10-29\n            ...       0
# 90   \n                    2018-10-30\n            ...       1
# 162  \n                    2018-10-30\n            ...       0
# 161  \n                    2018-10-30\n            ...       0
# 135  \n                    2018-10-30\n            ...       0
# 159  \n                    2018-10-30\n            ...       0
# 164  \n                    2018-10-30\n            ...       0
# 178  \n                    2018-10-30\n            ...       0
# 166  \n                    2018-10-31\n            ...       0
# 150  \n                    2018-10-31\n            ...       1
# 49   \n                    2018-11-01\n            ...       0
#
# [180 rows x 3 columns]

# %%
data.to_excel('非常6加1.xls')

# %% [markdown]
# # 《幸运52》

# %%
## 短评
comment2=[]
url_bas='https://movie.douban.com/subject/26087765/comments?start='
for i in range(0,180,20):
    url=url_bas+str(i)+'&limit=20&sort=new_score&status=P'
    html=urllib.request.urlopen(url)
    soup=BeautifulSoup(html,'html.parser')
    obj=soup.find_all('span',class_='short')
    for i in obj:
        comment2.append(i.text)

# %%
## 评论时间
date2=[]
url_bas='https://movie.douban.com/subject/26087765/comments?start='
for i in range(0,180,20):
    url=url_bas+str(i)+'&limit=20&sort=new_score&status=P'
    html=urllib.request.urlopen(url)
    soup=BeautifulSoup(html,'html.parser')
    obj=soup.find_all('span',class_='comment-time')
    for i in obj:
        date2.append(i.text)

# %%
## 支持数
support2=[]
url_bas='https://movie.douban.com/subject/26087765/comments?start='
for i in range(0,180,20):
    url=url_bas+str(i)+'&limit=20&sort=new_score&status=P'
    html=urllib.request.urlopen(url)
    soup=BeautifulSoup(html,'html.parser')
    obj=soup.find_all('span',class_='votes')
    for i in obj:
        support2.append(i.text)

# %%
data2=pd.DataFrame({'date':date2,'comment':comment2,'support':support2})
data2.sort_values('date',ascending=True)
# Out:
#                                                comment  \
# 9                                           还可以，李咏撑全场。
# 148                                                就这样
# 55                                              经典电视栏目
# 32                                             小时候每期必看
# 67                                    这都有。。。李咏出道之作啊。。。
# 158                       童年回忆，我爸爱看，不过“恭喜你，答错了”有些恶意了吧。
# 169                                               当年的了
# 38                                         那二年来说还是不错的。
# 104                    小时候超喜欢看，对主持人李咏和答对题目后的一枚枚商标印象深刻。
# 14                          李咏的节目印象最深就是《非常6+1》和《幸运52》。
# 28                                            哈文李咏的搭档。
# 131                                                 怀旧
# 2                                           当时的央视真是不一样
# 88                                           很老了，李咏主持的
# 63                                           我擦这都有%￥0￥
# 17                                     我只记得李咏一直在扔卡片。。。
# 16                                         少年时看电视猜题总是对
# 108                                    我妈原来喜欢看，我只看翻广告牌
# 30                                     还记得最强的一位参赛者叫李斯羽
# 24                                           马脸李咏 哈哈哈哈
# 140                                              年少的回忆
# 98     李咏的成名作。其实我是很欢迎老骨头们成批离开央视的。新鲜血液也许会带来一些教育程度更高的节目。
# 60                                                儿时记忆
# 94                                               儿时记忆了
# 99               名字太深刻了李咏太爱念口号了！这是我认识李咏的节目哈哈哈哈，没想到这也有。
# 3                                            —— 各種廣告商標
# 107                                       很棒的综艺，年少的回忆。
# 61                                     夫妻档节目。李咏的主持很生动。
# 34                                                童年回忆
# 4    小時候全家不看完不睡覺系列4，有人記得那會兒可以打168熱線參與答題嗎！哈哈哈哈哈去我媽單位...
# ..                                                 ...
# 122                                               咏哥走好
# 49                                                童年回忆
# 47                                算是童年的最喜欢的综艺启蒙了，咏哥走好。
# 165                                           小时候真的很喜欢
# 69                             分数这么低吗？感觉和现在的豆瓣网友格格不入了！
# 163                                                🙏🙏🙏
# 86                                                纪念李咏
# 75                                         就在刚才，李咏去世了…
# 76                              影响力很大的央视综艺，挺喜欢李咏的主持风格。
# 162  当年很有激情的节目，记得李咏一直在扔卡片，环节和环节之间李咏很有激情的声调。的确是一个商业化...
# 54                    每周，我都会和妈妈一起看，你画我猜那个环节最喜欢，一直想参加来着
# 136                                              咏哥走好！
# 138                                           少年时期的回忆了
# 155                                                 童年
# 154         来标记一下童年回忆。当时记得有个非常厉害的选手叫李斯羽，后来去当了美丽俏佳人的主持。
# 153  小时候真的很喜欢这个节目，反正每次看的都特别过瘾，完全被李咏的魅力所吸引，没有他这个节目我觉...
# 91                  看着人家拿走奖品，羡慕嫉妒恨，好想去参加！童年美好回忆，讲不出再见。
# 110                                        李咏老师谢谢您，再见。
# 7    商标启蒙：纳爱斯，月月舒，罗西尼，乔治白……太多了想不起来了，集满九宫格就离胜利不远了。你画...
# 87                                 满满的童年回忆，祝李咏老师一路走好🙏🙏
# 142                                               童年回忆
# 8                   90年出生的我 小时候周周看 还有开心辞典 纪念李咏老师 一路走好。
# 175                                               咏哥走好
# 29        印象最深的环节是猜东西价格高了低了，门槛低易借鉴。缅怀一下吧，尽管对主持人也谈不上喜欢。
# 168                                好像看电视的画面还是昨天，咏哥一路走好
# 125                                         永哥，天堂里没有病痛
# 95   昨天看到那个消息。很吃惊，你才50而已。我记得第一次认识你在幸运52这个节目。每周一次，每次...
# 124                                      童年回忆，一路走好🎙️🎙️
# 85               好喜欢那个砸金蛋的啊…当年就在想我长大了一定要打个电话去砸一下那个金蛋啊😭
# 177                                        很棒的节目，咏哥走好。
#
#                                                   date support
# 9    \n                    2015-01-10\n            ...       2
# 148  \n                    2015-01-10\n            ...       0
# 55   \n                    2015-03-03\n            ...       0
# 32   \n                    2015-04-18\n            ...       0
# 67   \n                    2015-04-26\n            ...       0
# 158  \n                    2015-05-10\n            ...       0
# 169  \n                    2015-05-15\n            ...       0
# 38   \n                    2015-05-20\n            ...       0
# 104  \n                    2015-05-23\n            ...       0
# 14   \n                    2015-07-04\n            ...       0
# 28   \n                    2015-07-15\n            ...       0
# 131  \n                    2015-07-20\n            ...       0
# 2    \n                    2015-07-23\n            ...      15
# 88   \n                    2015-07-27\n            ...       0
# 63   \n                    2015-08-08\n            ...       0
# 17   \n                    2015-08-09\n            ...       2
# 16   \n                    2015-08-19\n            ...       2
# 108  \n                    2015-09-03\n            ...       0
# 30   \n                    2015-09-24\n            ...       0
# 24   \n                    2015-11-09\n            ...       0
# 140  \n                    2015-12-01\n            ...       0
# 98   \n                    2015-12-07\n            ...       0
# 60   \n                    2016-01-21\n            ...       0
# 94   \n                    2016-01-24\n            ...       0
# 99   \n                    2016-01-27\n            ...       0
# 3    \n                    2016-02-07\n            ...       2
# 107  \n                    2016-02-07\n            ...       0
# 61   \n                    2016-02-08\n            ...       0
# 34   \n                    2016-02-08\n            ...       0
# 4    \n                    2016-02-08\n            ...       3
# ..                                                 ...     ...
# 122  \n                    2018-10-29\n            ...       0
# 49   \n                    2018-10-29\n            ...       0
# 47   \n                    2018-10-29\n            ...       1
# 165  \n                    2018-10-29\n            ...       0
# 69   \n                    2018-10-29\n            ...       0
# 163  \n                    2018-10-29\n            ...       0
# 86   \n                    2018-10-29\n            ...       0
# 75   \n                    2018-10-29\n            ...       0
# 76   \n                    2018-10-29\n            ...       0
# 162  \n                    2018-10-29\n            ...       0
# 54   \n                    2018-10-29\n            ...       0
# 136  \n                    2018-10-29\n            ...       0
# 138  \n                    2018-10-29\n            ...       1
# 155  \n                    2018-10-29\n            ...       0
# 154  \n                    2018-10-29\n            ...       1
# 153  \n                    2018-10-29\n            ...       0
# 91   \n                    2018-10-29\n            ...       0
# 110  \n                    2018-10-29\n            ...       0
# 7    \n                    2018-10-29\n            ...       2
# 87   \n                    2018-10-29\n            ...       0
# 142  \n                    2018-10-29\n            ...       0
# 8    \n                    2018-10-29\n            ...       5
# 175  \n                    2018-10-30\n            ...       1
# 29   \n                    2018-10-30\n            ...       1
# 168  \n                    2018-10-30\n            ...       0
# 125  \n                    2018-10-30\n            ...       1
# 95   \n                    2018-10-30\n            ...       0
# 124  \n                    2018-10-30\n            ...       1
# 85   \n                    2018-10-31\n            ...       0
# 177  \n                    2018-11-01\n            ...       0
#
# [180 rows x 3 columns]

# %%
data2.to_excel('幸运52.xls')

# %% [markdown]
# # 分词并画词云

# %%
from os import path
from wordcloud import WordCloud, ImageColorGenerator
import jieba
import pandas as pd
import numpy as np
from scipy.misc import imread
from PIL import Image

# %%
line=','.join(comment) #将list转化为str
word_list=jieba.cut(line,cut_all=False)
word_cut='，'.join(word_list)
#word_cut=list(word_list)
len(word_cut)
# Out:
# 5149

# %%
cloud_mask = np.array(Image.open('/Users/huxugang/Github/liyong.png'))

back_color = imread('/Users/huxugang/Github/liyong.png')
image_colors = ImageColorGenerator(back_color)


wd=WordCloud(font_path='/Users/huxugang/Github/TTF/Bemoji.ttf',#Bemoji   #kaiti   #Simhei
             background_color='white',max_words=500,
             max_font_size=50,
             random_state=15,
             width=2000,  # 图片的宽
             height=1000,  #图片的长
             mask=cloud_mask)
WD=wd.generate(word_cut)

import matplotlib.pyplot as plt
WD.to_file('whitenight.jpg')
# 显示词云图片
plt.figure(figsize=(10,10))
plt.axis('off')  #去掉坐标轴
plt.imshow(WD.recolor(color_func=image_colors))
#plt.show()
# Out:
# /Users/huxugang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
line=','.join(comment2) #将list转化为str
word_list=jieba.cut(line,cut_all=False)
word_cut='，'.join(word_list)
#word_cut=list(word_list)
len(word_cut)
# Out:
# 5706

# %%
cloud_mask = np.array(Image.open('/Users/huxugang/Github/liyong.png'))

back_color = imread('/Users/huxugang/Github/liyong.png')
image_colors = ImageColorGenerator(back_color)


wd=WordCloud(font_path='/Users/huxugang/Github/TTF/kaiti.ttf',#Bemoji   #kaiti   #Simhei
             background_color='white',max_words=1000,
             max_font_size=50,
             random_state=15,
             width=2000,  # 图片的宽
             height=1000,  #图片的长
             mask=cloud_mask)
WD=wd.generate(word_cut)

import matplotlib.pyplot as plt
WD.to_file('whitenight.jpg')
# 显示词云图片
plt.figure(figsize=(10,10))
plt.axis('off')  #去掉坐标轴
plt.imshow(WD.recolor(color_func=image_colors))
#plt.show()
# Out:
# /Users/huxugang/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
